# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
df=  pd.read_csv("train.csv")

# %%
#1. 
df.info()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2. 
print(df.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#3. 
df.dropna(inplace=True)

# %%
#4. 
df.describe(exclude = np)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
#5. 
corr_matrix = df.select_dtypes(include = ['float64','int64']).corr()
plt.figure(figsize=(12,5))
sns.heatmap(corr_matrix,annot=True)
plt.tight_layout()
plt.show()

# %%
#13. removing the outliers from the dataset : 

data = df.copy()
q1 = df.Fare.quantile(0.25)
q3 = df.Fare.quantile(0.75)
IQR  =q3-q1

min_value= q1 - IQR*1.5
max_value = q3 + IQR*1.5

outliers = df[(df.Fare < min_value) | (df.Fare> max_value)]
removed_outliers = df[(df.Fare >= min_value) & (df.Fare <= max_value)]
removed_outliers
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#12.
plt.boxplot(df[['PassengerId', 'Survived','Fare', 'Pclass', 'Age', 'SibSp','Parch']])
plt.show()

# %%
plt.scatter(df.Fare, df.Survived)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#8.
pd.plotting.parallel_coordinates(df,'Survived',cols=['Pclass','Fare','Age','PassengerId'])
# Out:
# <AxesSubplot:>

# %%
#10.
pd.plotting.scatter_matrix(df[['Age','Fare','Survived']])
# Out:
# array([[<AxesSubplot:xlabel='Age', ylabel='Age'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Age'>,
#         <AxesSubplot:xlabel='Survived', ylabel='Age'>],
#        [<AxesSubplot:xlabel='Age', ylabel='Fare'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Fare'>,
#         <AxesSubplot:xlabel='Survived', ylabel='Fare'>],
#        [<AxesSubplot:xlabel='Age', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Survived', ylabel='Survived'>]], dtype=object)

# %%
#9
sns.regplot(x=df.Age,y=df.Fare)
plt.show()

# %%
#11.
pd.crosstab(df.Survived,df.Sex,normalize='columns')
a = df[df.Sex =='male'].shape[0]
b=df[(df.Sex=='male')&(df.Survived==1)].shape[0]
b/a
# Out:
# 0.43157894736842106

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#13
data = df.copy()
q1 = df.Fare.quantile(0.25)
q3 = df.Fare.quantile(0.75)
IQR  =q3-q1

min_value= q1 - IQR*1.5
max_value = q3 + IQR*1.5

df = df[(df.Fare<=max_value)&(df.Fare>=min_value)]
print(df[df.Pclass==1]['Fare'].sum())
plt.scatter(df.Age,df.Fare)
# Out:
# 9450.070899999999

# %%
l=[]
for i in df.Age:
    if i<18: 
        l.append('chlid')
    elif i<30: 
        l.append('young')
    elif i<50 : 
        l.append('Ya')
    elif i<100:
        l.append('senior')
df.AgeGroup = np.array(l)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df.AgeGroup,df.Survived)
# Out:
# Survived   0   1
# row_0
# Ya        26  51
# chlid      2  16
# senior    18  16
# young     10  27

# %%
ag = pd.cut(df.Age ,bins=[0,18,30,50,100],labels=['child','young','Yound Adults','Senior'])
ag
# Out:
# 1      Yound Adults
# 3      Yound Adults
# 6            Senior
# 10            child
# 11           Senior
#            ...
# 871    Yound Adults
# 872    Yound Adults
# 879          Senior
# 887           young
# 889           young
# Name: Age, Length: 166, dtype: category
# Categories (4, object): ['child' < 'young' < 'Yound Adults' < 'Senior']
